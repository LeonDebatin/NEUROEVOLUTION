# %%
import pandas as pd
import numpy as np
import random
import csv

import sys
import os
parent_dir = os.path.abspath(os.path.join(os.path.dirname('../NEUROEVOLUTION'), '..'))
if parent_dir not in sys.path:
    sys.path.insert(0, parent_dir)


parent_dir = os.path.abspath(os.path.join(os.path.dirname('../gpolnel'), '..'))
if parent_dir not in sys.path:
    sys.path.insert(0, parent_dir)

from NEUROEVOLUTION.utils import drop_features, device, kfold, seed, save_best_params, load_best_params
from gp_utils import gp_cross_validation

from gpolnel.utils.ffunctions import Ffunctions
from gpolnel.utils.inductive_programming import function_map
from gpolnel.operators.initializers import ERC, grow, full, prm_grow
from NEUROEVOLUTION.gpolnel.operators.variators import swap_xo, prm_subtree_mtn, prm_hoist_mtn, prm_point_mtn
from NEUROEVOLUTION.gpolnel.operators.selectors import prm_tournament, prm_roulette_wheel, prm_rank_selection, prm_double_tournament

target = 'lactose'

# %%
X = pd.read_csv('../datamart/data_project_nel.csv')
y = pd.read_csv('../datamart/y_' + f'{target}'+ '.csv')['lactose_percent']
X = drop_features(X)

# %%
total_batches = 1
batch_size = X.shape[0]
shuffle = True
ffunction = Ffunctions('rmse')


initializers = [grow, full]

pss = [25, 50, 100, 250, 500, 1000]
n_iters = [25, 50, 100, 250]

fsets = [function_map['add'],  function_map['mul'], function_map['div'],function_map['sub']] #,  function_map['mean']]
constant_sets = [ERC(-1., 1.), ERC(-5., 5.), ERC(-10., 10.)]
p_constantss = [0.05, 0.1, 0.2, 0.3]

max_init_depths = [2, 3, 4, 5]
max_depths = [5, 6, 7, 8]

selection_pressures = [0.05, 0.1, 0.2, 0.3, 0.4]
selection_methods = [ prm_rank_selection, prm_tournament, prm_roulette_wheel]

mutation_probs = [0.05, 0.1, 0.15, 0.2, 0.5]
#mutation_methods = [prm_subtree_mtn(initializer=prm_grow), prm_hoist_mtn(), prm_point_mtn(sspace=sspace_sml, mutation_prob)]


xo_methods = [swap_xo]
xo_probs = [0.05, 0.2, 0.5, 0.7, 0.8, 0.9]

has_elitisms = [True, False]
allow_reproductions = [True, False]
import time

best_score = np.inf
name = 'logs/' +f'{target}' + '/random_search_total' + '.csv'
with open(name, 'w', newline='\n') as csvfile:
    w = csv.writer(csvfile, delimiter=';')
    w.writerow(['id'] + ['ps'] + ['n_iter'] +['initializer']+['sspace'] + ['selection_pressure'] + ['selection_method'] + ['mutation_prob'] + ['mutation_method'] + ['xo_prob'] + ['xo_method'] + ['has_elitism'] + ['allow_reproduction'] + ['score'])


for i in range(1, 100):
    
    initializer = random.choice(initializers)
    ps = random.choice(pss)
    n_iter = random.choice(n_iters)

    fset = random.sample(fsets, random.randint(1, len(fsets)))
    constant_set = random.choice(constant_sets)
    p_constants = random.choice(p_constantss)
    
    max_init_depth = random.choice(max_init_depths)
    max_depth = random.choice(max_depths)

    sspace = {
        'n_dims': X.shape[1],
        'function_set': fset, 'constant_set': constant_set,
        'p_constants': p_constants,
        'max_init_depth': max_init_depth,
        'max_depth': max_depth,
        'n_batches': total_batches,
        'device': device
        }
    selection_pressures = [0.05, 0.1, 0.2, 0.3, 0.4]
    selection_pressure = random.choice(selection_pressures)
    selection_methods = [ prm_tournament(selection_pressure), prm_rank_selection(), prm_double_tournament(selection_pressure, selection_pressure)]
    selection_method = random.choice(selection_methods)
    
    
    mutation_prob = random.choice(mutation_probs)
    mutation_methods = [prm_subtree_mtn(initializer=prm_grow(sspace=sspace)), prm_hoist_mtn(), prm_point_mtn(sspace=sspace, prob=mutation_prob)]
    mutation_method = random.choice(mutation_methods)
    
    xo_prob = random.choice(xo_probs)
    xo_method = random.choice(xo_methods)
    
    has_elitism = random.choice(has_elitisms)
    allow_reproduction = random.choice(allow_reproductions)
    

    log_path_cv = 'logs/' + f'{target}'+'/' + f'{i}' + '_cv_results.csv'
    log_path_train = 'logs/'+ f'{target}'+ '/train_logs.csv'
    
    
    print(initializer, ps, n_iter, sspace, selection_pressure, selection_method, mutation_prob, mutation_method, xo_prob, xo_method, has_elitism, allow_reproduction, log_path_cv, log_path_train, ffunction, seed, device, i)
    
    score = gp_cross_validation(X, y, batch_size, shuffle, kfold, 
                                initializer=initializer, ps=ps, n_iter=n_iter, 
                                sspace=sspace, 
                                selection_method=selection_method, 
                                mutation_prob=mutation_prob, 
                                mutation_method=mutation_method, 
                                xo_prob=xo_prob, xo_method=xo_method, 
                                has_elitism=has_elitism, 
                                allow_reproduction=allow_reproduction, 
                                log_path_cv=log_path_cv, log_path_train=log_path_train,
                                ffunction=ffunction, seed=seed, device=device, id=i)
    
    # Write all parameters with score as f-strings
    with open(name, 'a', newline='\n') as csvfile:
        w = csv.writer(csvfile, delimiter=';')
        w.writerow([i] + [ps] + [n_iter] + [initializer] + [sspace] + [selection_pressure] + [selection_method] + [mutation_prob] + [mutation_method] + [xo_prob] + [xo_method] + [has_elitism] + [allow_reproduction] + [score])
    
    if score < best_score:
        best_score = score
        print(f'New best cv_score: {best_score} at search {i}')
        best_params = {
            'X': X,
            'y': y,
            'batch_size': batch_size,
            'shuffle': shuffle,
            'kfold': kfold,
            'initializer': initializer,
            'ps': ps,
            'n_iter': n_iter,
            'sspace': sspace,
            'selection_pressure': selection_pressure,
            'selection_method': f'{selection_method}',
            'mutation_prob': mutation_prob,
            'mutation_method': f'{mutation_method}',
            'xo_prob': xo_prob,
            'xo_method': f'{xo_method}',
            'has_elitism': has_elitism,
            'allow_reproduction': allow_reproduction,
            'log_path_cv': log_path_cv,
            'log_path_train': log_path_train,
            'ffunction': ffunction,
            'seed': seed,
            'device': device,
            'id': i,
        }
        save_best_params('best_params/'+ f'{target}' + '-best_params-' + f'{i}' +'.pkl', best_params)
# Out:
# <function grow at 0x00000280152AE340> 50 10 {'n_dims': 12, 'function_set': [add, mul, div], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x0000028014CC1850>, 'p_constants': 0.3, 'max_init_depth': 3, 'max_depth': 5, 'n_batches': 1, 'device': 'cpu'} 0.3 <function prm_tournament.<locals>.tournament at 0x00000280152AF920> 0.2 <function prm_hoist_mtn.<locals>.hoist_mtn at 0x00000280152AFCE0> 0.8 <function swap_xo at 0x00000280152AEC00> False False logs/lactose/1_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 1
# cv_score: 1.2354116
# New best cv_score: 1.2354116439819336 at search 1
# <function grow at 0x00000280152AE340> 50 10 {'n_dims': 12, 'function_set': [sub, mul], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x0000028014CC1850>, 'p_constants': 0.2, 'max_init_depth': 3, 'max_depth': 7, 'n_batches': 1, 'device': 'cpu'} 0.4 <function prm_tournament.<locals>.tournament at 0x00000280153AC7C0> 0.15 <function prm_point_mtn.<locals>.point_mtn at 0x00000280153AEC00> 0.2 <function swap_xo at 0x00000280152AEC00> False True logs/lactose/2_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 2
# cv_score: 1.8191862
# <function full at 0x00000280152AE520> 50 10 {'n_dims': 12, 'function_set': [mul, sub, add], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x00000280152B32D0>, 'p_constants': 0.1, 'max_init_depth': 3, 'max_depth': 6, 'n_batches': 1, 'device': 'cpu'} 0.3 <function prm_double_tournament.<locals>.double_tournament at 0x00000280152AF880> 0.1 <function prm_subtree_mtn.<locals>.subtree_mtn at 0x00000280152AFEC0> 0.9 <function swap_xo at 0x00000280152AEC00> False True logs/lactose/3_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 3
# cv_score: 0.64253163
# New best cv_score: 0.6425316333770752 at search 3
# <function full at 0x00000280152AE520> 50 10 {'n_dims': 12, 'function_set': [sub, mul, div, add], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x00000280152B32D0>, 'p_constants': 0.3, 'max_init_depth': 3, 'max_depth': 8, 'n_batches': 1, 'device': 'cpu'} 0.3 <function prm_rank_selection.<locals>.rank_selection at 0x00000280153ACAE0> 0.05 <function prm_subtree_mtn.<locals>.subtree_mtn at 0x00000280152AF7E0> 0.9 <function swap_xo at 0x00000280152AEC00> False False logs/lactose/4_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 4
# cv_score: 1.5152773
# <function full at 0x00000280152AE520> 50 10 {'n_dims': 12, 'function_set': [mul, div], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x00000280152B3350>, 'p_constants': 0.3, 'max_init_depth': 4, 'max_depth': 6, 'n_batches': 1, 'device': 'cpu'} 0.2 <function prm_tournament.<locals>.tournament at 0x0000028015383600> 0.05 <function prm_point_mtn.<locals>.point_mtn at 0x0000028015534C20> 0.2 <function swap_xo at 0x00000280152AEC00> False False logs/lactose/5_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 5
# cv_score: 3.8128319
# <function grow at 0x00000280152AE340> 50 10 {'n_dims': 12, 'function_set': [mul, div, add], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x0000028014CC1850>, 'p_constants': 0.05, 'max_init_depth': 2, 'max_depth': 5, 'n_batches': 1, 'device': 'cpu'} 0.1 <function prm_double_tournament.<locals>.double_tournament at 0x0000028015507C40> 0.15 <function prm_hoist_mtn.<locals>.hoist_mtn at 0x00000280152AFBA0> 0.7 <function swap_xo at 0x00000280152AEC00> True True logs/lactose/6_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 6
# cv_score: 0.72869986
# <function full at 0x00000280152AE520> 50 10 {'n_dims': 12, 'function_set': [sub, div, add, mul], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x00000280152B3350>, 'p_constants': 0.05, 'max_init_depth': 2, 'max_depth': 7, 'n_batches': 1, 'device': 'cpu'} 0.2 <function prm_rank_selection.<locals>.rank_selection at 0x0000028015504B80> 0.5 <function prm_subtree_mtn.<locals>.subtree_mtn at 0x0000028015506980> 0.9 <function swap_xo at 0x00000280152AEC00> True False logs/lactose/7_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 7
# cv_score: 0.7124172
# <function grow at 0x00000280152AE340> 50 10 {'n_dims': 12, 'function_set': [mul, add, sub, div], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x00000280152B3350>, 'p_constants': 0.1, 'max_init_depth': 2, 'max_depth': 5, 'n_batches': 1, 'device': 'cpu'} 0.4 <function prm_rank_selection.<locals>.rank_selection at 0x0000028015504E00> 0.2 <function prm_subtree_mtn.<locals>.subtree_mtn at 0x0000028015606E80> 0.2 <function swap_xo at 0x00000280152AEC00> True False logs/lactose/8_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 8
# cv_score: 0.6209965
# New best cv_score: 0.6209964752197266 at search 8
# <function grow at 0x00000280152AE340> 50 10 {'n_dims': 12, 'function_set': [mul, sub, add, div], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x00000280152B32D0>, 'p_constants': 0.1, 'max_init_depth': 2, 'max_depth': 8, 'n_batches': 1, 'device': 'cpu'} 0.1 <function prm_tournament.<locals>.tournament at 0x00000280155A5D00> 0.1 <function prm_hoist_mtn.<locals>.hoist_mtn at 0x00000280155349A0> 0.05 <function swap_xo at 0x00000280152AEC00> True True logs/lactose/9_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 9
# cv_score: 0.72869986
# <function grow at 0x00000280152AE340> 50 10 {'n_dims': 12, 'function_set': [sub, add, div], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x0000028014CC1850>, 'p_constants': 0.3, 'max_init_depth': 4, 'max_depth': 7, 'n_batches': 1, 'device': 'cpu'} 0.1 <function prm_double_tournament.<locals>.double_tournament at 0x000002801564BF60> 0.05 <function prm_subtree_mtn.<locals>.subtree_mtn at 0x00000280155AF4C0> 0.7 <function swap_xo at 0x00000280152AEC00> True False logs/lactose/10_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 10
# cv_score: 0.45564127
# New best cv_score: 0.4556412696838379 at search 10
# <function full at 0x00000280152AE520> 50 10 {'n_dims': 12, 'function_set': [div, add], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x00000280152B3350>, 'p_constants': 0.3, 'max_init_depth': 3, 'max_depth': 7, 'n_batches': 1, 'device': 'cpu'} 0.2 <function prm_tournament.<locals>.tournament at 0x00000280155C99E0> 0.1 <function prm_point_mtn.<locals>.point_mtn at 0x0000028015640E00> 0.05 <function swap_xo at 0x00000280152AEC00> False False logs/lactose/11_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 11
# cv_score: 0.73545474
# <function full at 0x00000280152AE520> 50 10 {'n_dims': 12, 'function_set': [mul, div, sub], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x00000280152B32D0>, 'p_constants': 0.3, 'max_init_depth': 5, 'max_depth': 5, 'n_batches': 1, 'device': 'cpu'} 0.2 <function prm_rank_selection.<locals>.rank_selection at 0x00000280155BEB60> 0.1 <function prm_subtree_mtn.<locals>.subtree_mtn at 0x0000028015537560> 0.5 <function swap_xo at 0x00000280152AEC00> False False logs/lactose/12_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 12
# cv_score: 39.30256
# <function full at 0x00000280152AE520> 50 10 {'n_dims': 12, 'function_set': [sub], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x00000280152B32D0>, 'p_constants': 0.05, 'max_init_depth': 5, 'max_depth': 8, 'n_batches': 1, 'device': 'cpu'} 0.3 <function prm_tournament.<locals>.tournament at 0x0000028015648360> 0.05 <function prm_subtree_mtn.<locals>.subtree_mtn at 0x00000280155BE980> 0.9 <function swap_xo at 0x00000280152AEC00> True False logs/lactose/13_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 13
# cv_score: 0.8739379
# <function grow at 0x00000280152AE340> 50 10 {'n_dims': 12, 'function_set': [sub, mul, div, add], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x00000280152B3350>, 'p_constants': 0.05, 'max_init_depth': 2, 'max_depth': 5, 'n_batches': 1, 'device': 'cpu'} 0.1 <function prm_double_tournament.<locals>.double_tournament at 0x00000280156F4C20> 0.1 <function prm_point_mtn.<locals>.point_mtn at 0x000002801569B880> 0.7 <function swap_xo at 0x00000280152AEC00> True True logs/lactose/14_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 14
# cv_score: 0.7115137
# <function grow at 0x00000280152AE340> 50 10 {'n_dims': 12, 'function_set': [mul, sub, add], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x00000280152B32D0>, 'p_constants': 0.1, 'max_init_depth': 3, 'max_depth': 8, 'n_batches': 1, 'device': 'cpu'} 0.1 <function prm_tournament.<locals>.tournament at 0x00000280155BEB60> 0.1 <function prm_subtree_mtn.<locals>.subtree_mtn at 0x00000280156419E0> 0.8 <function swap_xo at 0x00000280152AEC00> True False logs/lactose/15_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 15
# cv_score: 0.24811251
# New best cv_score: 0.2481125146150589 at search 15
# <function grow at 0x00000280152AE340> 50 10 {'n_dims': 12, 'function_set': [div], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x00000280152B3350>, 'p_constants': 0.3, 'max_init_depth': 2, 'max_depth': 5, 'n_batches': 1, 'device': 'cpu'} 0.05 <function prm_double_tournament.<locals>.double_tournament at 0x00000280157134C0> 0.15 <function prm_point_mtn.<locals>.point_mtn at 0x0000028015713C40> 0.5 <function swap_xo at 0x00000280152AEC00> False False logs/lactose/16_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 16
# cv_score: 0.90955096
# <function full at 0x00000280152AE520> 50 10 {'n_dims': 12, 'function_set': [add], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x0000028014CC1850>, 'p_constants': 0.05, 'max_init_depth': 5, 'max_depth': 6, 'n_batches': 1, 'device': 'cpu'} 0.2 <function prm_double_tournament.<locals>.double_tournament at 0x000002801577CEA0> 0.2 <function prm_subtree_mtn.<locals>.subtree_mtn at 0x0000028015712C00> 0.5 <function swap_xo at 0x00000280152AEC00> False False logs/lactose/17_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 17
# cv_score: 0.64253163
# <function grow at 0x00000280152AE340> 50 10 {'n_dims': 12, 'function_set': [add, mul, div, sub], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x0000028014CC1850>, 'p_constants': 0.05, 'max_init_depth': 2, 'max_depth': 6, 'n_batches': 1, 'device': 'cpu'} 0.1 <function prm_double_tournament.<locals>.double_tournament at 0x0000028015759EE0> 0.05 <function prm_subtree_mtn.<locals>.subtree_mtn at 0x0000028015698860> 0.9 <function swap_xo at 0x00000280152AEC00> True False logs/lactose/18_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 18
# cv_score: 0.61660874
# <function full at 0x00000280152AE520> 50 10 {'n_dims': 12, 'function_set': [sub, add, div], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x00000280152B32D0>, 'p_constants': 0.1, 'max_init_depth': 2, 'max_depth': 6, 'n_batches': 1, 'device': 'cpu'} 0.1 <function prm_tournament.<locals>.tournament at 0x000002801579C220> 0.1 <function prm_hoist_mtn.<locals>.hoist_mtn at 0x00000280156FF2E0> 0.05 <function swap_xo at 0x00000280152AEC00> False True logs/lactose/19_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 19
# cv_score: 1.4851335
# <function full at 0x00000280152AE520> 50 10 {'n_dims': 12, 'function_set': [add], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x00000280152B32D0>, 'p_constants': 0.1, 'max_init_depth': 4, 'max_depth': 8, 'n_batches': 1, 'device': 'cpu'} 0.05 <function prm_tournament.<locals>.tournament at 0x00000280157134C0> 0.15 <function prm_point_mtn.<locals>.point_mtn at 0x000002801577CC20> 0.9 <function swap_xo at 0x00000280152AEC00> True True logs/lactose/20_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 20
# cv_score: 1.0110295
# <function full at 0x00000280152AE520> 50 10 {'n_dims': 12, 'function_set': [div, add, mul], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x0000028014CC1850>, 'p_constants': 0.05, 'max_init_depth': 2, 'max_depth': 7, 'n_batches': 1, 'device': 'cpu'} 0.2 <function prm_rank_selection.<locals>.rank_selection at 0x00000280156F4C20> 0.1 <function prm_hoist_mtn.<locals>.hoist_mtn at 0x000002801573CD60> 0.7 <function swap_xo at 0x00000280152AEC00> True True logs/lactose/21_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 21
# cv_score: 1.1462739
# <function full at 0x00000280152AE520> 50 10 {'n_dims': 12, 'function_set': [mul, div], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x00000280152B3350>, 'p_constants': 0.1, 'max_init_depth': 2, 'max_depth': 8, 'n_batches': 1, 'device': 'cpu'} 0.4 <function prm_double_tournament.<locals>.double_tournament at 0x00000280157C0F40> 0.1 <function prm_hoist_mtn.<locals>.hoist_mtn at 0x00000280157DB1A0> 0.2 <function swap_xo at 0x00000280152AEC00> False True logs/lactose/22_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 22
# cv_score: 2.238359
# <function grow at 0x00000280152AE340> 50 10 {'n_dims': 12, 'function_set': [add, div, mul], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x0000028014CC1850>, 'p_constants': 0.3, 'max_init_depth': 3, 'max_depth': 6, 'n_batches': 1, 'device': 'cpu'} 0.05 <function prm_rank_selection.<locals>.rank_selection at 0x0000028015806700> 0.2 <function prm_point_mtn.<locals>.point_mtn at 0x000002801579C220> 0.5 <function swap_xo at 0x00000280152AEC00> False True logs/lactose/23_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 23
# cv_score: 1.4257728
# <function grow at 0x00000280152AE340> 50 10 {'n_dims': 12, 'function_set': [div, sub], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x0000028014CC1850>, 'p_constants': 0.1, 'max_init_depth': 4, 'max_depth': 5, 'n_batches': 1, 'device': 'cpu'} 0.05 <function prm_tournament.<locals>.tournament at 0x00000280158A4040> 0.5 <function prm_hoist_mtn.<locals>.hoist_mtn at 0x0000028015806700> 0.05 <function swap_xo at 0x00000280152AEC00> True True logs/lactose/24_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 24
# cv_score: 2.1037965
# <function full at 0x00000280152AE520> 50 10 {'n_dims': 12, 'function_set': [mul, div, add], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x0000028014CC1850>, 'p_constants': 0.05, 'max_init_depth': 5, 'max_depth': 8, 'n_batches': 1, 'device': 'cpu'} 0.4 <function prm_double_tournament.<locals>.double_tournament at 0x0000028015833EC0> 0.1 <function prm_point_mtn.<locals>.point_mtn at 0x00000280158689A0> 0.7 <function swap_xo at 0x00000280152AEC00> False False logs/lactose/25_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 25
# cv_score: 3.6029553
# <function full at 0x00000280152AE520> 50 10 {'n_dims': 12, 'function_set': [add, div, mul], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x00000280152B3350>, 'p_constants': 0.05, 'max_init_depth': 3, 'max_depth': 6, 'n_batches': 1, 'device': 'cpu'} 0.3 <function prm_tournament.<locals>.tournament at 0x0000028015804900> 0.5 <function prm_subtree_mtn.<locals>.subtree_mtn at 0x0000028015779580> 0.8 <function swap_xo at 0x00000280152AEC00> False False logs/lactose/26_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 26
# cv_score: 1.0059283
# <function grow at 0x00000280152AE340> 50 10 {'n_dims': 12, 'function_set': [div, mul, sub, add], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x0000028014CC1850>, 'p_constants': 0.05, 'max_init_depth': 4, 'max_depth': 5, 'n_batches': 1, 'device': 'cpu'} 0.4 <function prm_double_tournament.<locals>.double_tournament at 0x00000280158CFA60> 0.5 <function prm_point_mtn.<locals>.point_mtn at 0x00000280158A5760> 0.05 <function swap_xo at 0x00000280152AEC00> False True logs/lactose/27_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 27
# cv_score: 0.37785527
# <function grow at 0x00000280152AE340> 50 10 {'n_dims': 12, 'function_set': [add, sub, mul, div], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x00000280152B32D0>, 'p_constants': 0.3, 'max_init_depth': 3, 'max_depth': 5, 'n_batches': 1, 'device': 'cpu'} 0.2 <function prm_double_tournament.<locals>.double_tournament at 0x000002801594B7E0> 0.2 <function prm_point_mtn.<locals>.point_mtn at 0x00000280158CE980> 0.2 <function swap_xo at 0x00000280152AEC00> False True logs/lactose/28_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 28
# cv_score: 0.4606995
# <function full at 0x00000280152AE520> 50 10 {'n_dims': 12, 'function_set': [sub, mul], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x00000280152B32D0>, 'p_constants': 0.2, 'max_init_depth': 5, 'max_depth': 8, 'n_batches': 1, 'device': 'cpu'} 0.3 <function prm_rank_selection.<locals>.rank_selection at 0x00000280158DC400> 0.5 <function prm_subtree_mtn.<locals>.subtree_mtn at 0x00000280158EE980> 0.2 <function swap_xo at 0x00000280152AEC00> True True logs/lactose/29_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 29
# cv_score: 2.7006218
# <function full at 0x00000280152AE520> 50 10 {'n_dims': 12, 'function_set': [add, sub, div], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x00000280152B3350>, 'p_constants': 0.2, 'max_init_depth': 3, 'max_depth': 7, 'n_batches': 1, 'device': 'cpu'} 0.05 <function prm_double_tournament.<locals>.double_tournament at 0x000002801584E3E0> 0.2 <function prm_point_mtn.<locals>.point_mtn at 0x00000280158DF740> 0.8 <function swap_xo at 0x00000280152AEC00> False False logs/lactose/30_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 30
# cv_score: 0.6085815
# <function grow at 0x00000280152AE340> 50 10 {'n_dims': 12, 'function_set': [mul, div, sub, add], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x00000280152B32D0>, 'p_constants': 0.05, 'max_init_depth': 5, 'max_depth': 6, 'n_batches': 1, 'device': 'cpu'} 0.05 <function prm_rank_selection.<locals>.rank_selection at 0x00000280158A74C0> 0.15 <function prm_point_mtn.<locals>.point_mtn at 0x00000280159A1C60> 0.2 <function swap_xo at 0x00000280152AEC00> True False logs/lactose/31_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 31
# cv_score: 0.7815759
# <function full at 0x00000280152AE520> 50 10 {'n_dims': 12, 'function_set': [add, mul, sub], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x00000280152B32D0>, 'p_constants': 0.05, 'max_init_depth': 5, 'max_depth': 6, 'n_batches': 1, 'device': 'cpu'} 0.3 <function prm_rank_selection.<locals>.rank_selection at 0x00000280158DC400> 0.1 <function prm_hoist_mtn.<locals>.hoist_mtn at 0x0000028015937E20> 0.5 <function swap_xo at 0x00000280152AEC00> False False logs/lactose/32_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 32
# cv_score: 23.3604
# <function full at 0x00000280152AE520> 50 10 {'n_dims': 12, 'function_set': [sub], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x00000280152B3350>, 'p_constants': 0.05, 'max_init_depth': 5, 'max_depth': 5, 'n_batches': 1, 'device': 'cpu'} 0.3 <function prm_double_tournament.<locals>.double_tournament at 0x0000028015960B80> 0.5 <function prm_subtree_mtn.<locals>.subtree_mtn at 0x00000280158DEF20> 0.9 <function swap_xo at 0x00000280152AEC00> False False logs/lactose/33_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 33
# cv_score: 1.247814
# <function grow at 0x00000280152AE340> 50 10 {'n_dims': 12, 'function_set': [mul, sub, div, add], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x00000280152B3350>, 'p_constants': 0.3, 'max_init_depth': 5, 'max_depth': 8, 'n_batches': 1, 'device': 'cpu'} 0.3 <function prm_double_tournament.<locals>.double_tournament at 0x0000028015A428E0> 0.15 <function prm_point_mtn.<locals>.point_mtn at 0x0000028015934900> 0.2 <function swap_xo at 0x00000280152AEC00> False True logs/lactose/34_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 34
# cv_score: 0.6354078
# <function grow at 0x00000280152AE340> 50 10 {'n_dims': 12, 'function_set': [div], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x0000028014CC1850>, 'p_constants': 0.3, 'max_init_depth': 2, 'max_depth': 6, 'n_batches': 1, 'device': 'cpu'} 0.4 <function prm_rank_selection.<locals>.rank_selection at 0x0000028015A43560> 0.2 <function prm_point_mtn.<locals>.point_mtn at 0x000002801598AF20> 0.7 <function swap_xo at 0x00000280152AEC00> True False logs/lactose/35_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 35
# cv_score: 1.6131489
# <function full at 0x00000280152AE520> 50 10 {'n_dims': 12, 'function_set': [add, mul, div], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x00000280152B3350>, 'p_constants': 0.1, 'max_init_depth': 5, 'max_depth': 7, 'n_batches': 1, 'device': 'cpu'} 0.3 <function prm_double_tournament.<locals>.double_tournament at 0x0000028015A5CF40> 0.1 <function prm_hoist_mtn.<locals>.hoist_mtn at 0x00000280159BD580> 0.9 <function swap_xo at 0x00000280152AEC00> True False logs/lactose/36_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 36
# cv_score: 1.3211204
# <function grow at 0x00000280152AE340> 50 10 {'n_dims': 12, 'function_set': [sub, div, mul, add], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x00000280152B3350>, 'p_constants': 0.1, 'max_init_depth': 3, 'max_depth': 6, 'n_batches': 1, 'device': 'cpu'} 0.2 <function prm_rank_selection.<locals>.rank_selection at 0x0000028015971760> 0.5 <function prm_point_mtn.<locals>.point_mtn at 0x00000280158F3CE0> 0.8 <function swap_xo at 0x00000280152AEC00> True True logs/lactose/37_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 37
# cv_score: 0.6568335
# <function full at 0x00000280152AE520> 50 10 {'n_dims': 12, 'function_set': [sub], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x00000280152B3350>, 'p_constants': 0.1, 'max_init_depth': 5, 'max_depth': 5, 'n_batches': 1, 'device': 'cpu'} 0.4 <function prm_rank_selection.<locals>.rank_selection at 0x00000280158F1580> 0.5 <function prm_point_mtn.<locals>.point_mtn at 0x00000280158F04A0> 0.05 <function swap_xo at 0x00000280152AEC00> True False logs/lactose/38_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 38
# cv_score: 2.8789136
# <function grow at 0x00000280152AE340> 50 10 {'n_dims': 12, 'function_set': [add, div, mul], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x00000280152B3350>, 'p_constants': 0.2, 'max_init_depth': 3, 'max_depth': 6, 'n_batches': 1, 'device': 'cpu'} 0.3 <function prm_double_tournament.<locals>.double_tournament at 0x00000280159F37E0> 0.1 <function prm_point_mtn.<locals>.point_mtn at 0x0000028015ACF7E0> 0.9 <function swap_xo at 0x00000280152AEC00> False True logs/lactose/39_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 39
# cv_score: 1.2597307
# <function full at 0x00000280152AE520> 50 10 {'n_dims': 12, 'function_set': [mul, sub, add], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x0000028014CC1850>, 'p_constants': 0.05, 'max_init_depth': 5, 'max_depth': 7, 'n_batches': 1, 'device': 'cpu'} 0.4 <function prm_double_tournament.<locals>.double_tournament at 0x0000028015AD8EA0> 0.5 <function prm_point_mtn.<locals>.point_mtn at 0x0000028015ADA160> 0.2 <function swap_xo at 0x00000280152AEC00> False True logs/lactose/40_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 40
# cv_score: 4.8932853
# <function full at 0x00000280152AE520> 50 10 {'n_dims': 12, 'function_set': [mul, sub], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x0000028014CC1850>, 'p_constants': 0.3, 'max_init_depth': 3, 'max_depth': 7, 'n_batches': 1, 'device': 'cpu'} 0.4 <function prm_double_tournament.<locals>.double_tournament at 0x0000028015B18180> 0.5 <function prm_subtree_mtn.<locals>.subtree_mtn at 0x00000280159DDB20> 0.9 <function swap_xo at 0x00000280152AEC00> False False logs/lactose/41_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 41
# cv_score: 0.37324673
# <function grow at 0x00000280152AE340> 50 10 {'n_dims': 12, 'function_set': [div, sub, add], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x00000280152B3350>, 'p_constants': 0.05, 'max_init_depth': 2, 'max_depth': 6, 'n_batches': 1, 'device': 'cpu'} 0.2 <function prm_tournament.<locals>.tournament at 0x0000028015AFAD40> 0.15 <function prm_subtree_mtn.<locals>.subtree_mtn at 0x0000028015B2DBC0> 0.2 <function swap_xo at 0x00000280152AEC00> True False logs/lactose/42_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 42
# cv_score: 0.5965242
# <function full at 0x00000280152AE520> 50 10 {'n_dims': 12, 'function_set': [mul, add, sub], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x0000028014CC1850>, 'p_constants': 0.2, 'max_init_depth': 4, 'max_depth': 7, 'n_batches': 1, 'device': 'cpu'} 0.4 <function prm_double_tournament.<locals>.double_tournament at 0x0000028015B089A0> 0.5 <function prm_subtree_mtn.<locals>.subtree_mtn at 0x00000280158F04A0> 0.8 <function swap_xo at 0x00000280152AEC00> True False logs/lactose/43_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 43
# cv_score: 0.579151
# <function grow at 0x00000280152AE340> 50 10 {'n_dims': 12, 'function_set': [div, mul, sub, add], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x00000280152B32D0>, 'p_constants': 0.3, 'max_init_depth': 2, 'max_depth': 8, 'n_batches': 1, 'device': 'cpu'} 0.1 <function prm_rank_selection.<locals>.rank_selection at 0x0000028015B6EE80> 0.5 <function prm_point_mtn.<locals>.point_mtn at 0x0000028015A63D80> 0.9 <function swap_xo at 0x00000280152AEC00> True True logs/lactose/44_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 44
# cv_score: 0.5948993
# <function grow at 0x00000280152AE340> 50 10 {'n_dims': 12, 'function_set': [sub, mul], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x00000280152B32D0>, 'p_constants': 0.05, 'max_init_depth': 4, 'max_depth': 6, 'n_batches': 1, 'device': 'cpu'} 0.1 <function prm_rank_selection.<locals>.rank_selection at 0x0000028015C3BCE0> 0.5 <function prm_point_mtn.<locals>.point_mtn at 0x0000028015B6F740> 0.8 <function swap_xo at 0x00000280152AEC00> False True logs/lactose/45_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 45
# cv_score: 2.1487486
# <function grow at 0x00000280152AE340> 50 10 {'n_dims': 12, 'function_set': [div, sub], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x0000028014CC1850>, 'p_constants': 0.2, 'max_init_depth': 2, 'max_depth': 5, 'n_batches': 1, 'device': 'cpu'} 0.05 <function prm_rank_selection.<locals>.rank_selection at 0x0000028015B47CE0> 0.5 <function prm_subtree_mtn.<locals>.subtree_mtn at 0x0000028015BEA2A0> 0.05 <function swap_xo at 0x00000280152AEC00> True True logs/lactose/46_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 46
# cv_score: 0.47906184
# <function grow at 0x00000280152AE340> 50 10 {'n_dims': 12, 'function_set': [add, div, sub, mul], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x0000028014CC1850>, 'p_constants': 0.3, 'max_init_depth': 5, 'max_depth': 5, 'n_batches': 1, 'device': 'cpu'} 0.1 <function prm_tournament.<locals>.tournament at 0x0000028015C4DA80> 0.2 <function prm_subtree_mtn.<locals>.subtree_mtn at 0x0000028015BCC180> 0.8 <function swap_xo at 0x00000280152AEC00> False False logs/lactose/47_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 47
# cv_score: 0.46007842
# <function grow at 0x00000280152AE340> 50 10 {'n_dims': 12, 'function_set': [div], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x00000280152B32D0>, 'p_constants': 0.1, 'max_init_depth': 2, 'max_depth': 6, 'n_batches': 1, 'device': 'cpu'} 0.1 <function prm_tournament.<locals>.tournament at 0x0000028015C92480> 0.15 <function prm_subtree_mtn.<locals>.subtree_mtn at 0x0000028015C4D580> 0.2 <function swap_xo at 0x00000280152AEC00> False True logs/lactose/48_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 48
# cv_score: 1.072067
# <function grow at 0x00000280152AE340> 50 10 {'n_dims': 12, 'function_set': [add, mul, div, sub], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x00000280152B32D0>, 'p_constants': 0.2, 'max_init_depth': 3, 'max_depth': 5, 'n_batches': 1, 'device': 'cpu'} 0.4 <function prm_tournament.<locals>.tournament at 0x0000028015B47CE0> 0.15 <function prm_point_mtn.<locals>.point_mtn at 0x0000028015C92A20> 0.05 <function swap_xo at 0x00000280152AEC00> False True logs/lactose/49_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 49
# cv_score: 0.69786227
# <function full at 0x00000280152AE520> 50 10 {'n_dims': 12, 'function_set': [mul, sub, add], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x00000280152B32D0>, 'p_constants': 0.1, 'max_init_depth': 3, 'max_depth': 6, 'n_batches': 1, 'device': 'cpu'} 0.3 <function prm_double_tournament.<locals>.double_tournament at 0x0000028015C90EA0> 0.1 <function prm_subtree_mtn.<locals>.subtree_mtn at 0x0000028015BB56C0> 0.9 <function swap_xo at 0x00000280152AEC00> False True logs/lactose/50_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 50
# cv_score: 0.64253163
# <function full at 0x00000280152AE520> 50 10 {'n_dims': 12, 'function_set': [sub, mul, div, add], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x00000280152B32D0>, 'p_constants': 0.3, 'max_init_depth': 3, 'max_depth': 8, 'n_batches': 1, 'device': 'cpu'} 0.3 <function prm_rank_selection.<locals>.rank_selection at 0x0000028015CB3420> 0.05 <function prm_subtree_mtn.<locals>.subtree_mtn at 0x0000028015CB2F20> 0.9 <function swap_xo at 0x00000280152AEC00> False False logs/lactose/51_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 51
# cv_score: 1.5152773
# <function full at 0x00000280152AE520> 50 10 {'n_dims': 12, 'function_set': [mul, div], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x00000280152B3350>, 'p_constants': 0.3, 'max_init_depth': 4, 'max_depth': 6, 'n_batches': 1, 'device': 'cpu'} 0.2 <function prm_tournament.<locals>.tournament at 0x0000028015B47CE0> 0.05 <function prm_point_mtn.<locals>.point_mtn at 0x0000028015CB0FE0> 0.2 <function swap_xo at 0x00000280152AEC00> False False logs/lactose/52_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 52
# cv_score: 3.8128319
# <function grow at 0x00000280152AE340> 50 10 {'n_dims': 12, 'function_set': [mul, div, add], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x0000028014CC1850>, 'p_constants': 0.05, 'max_init_depth': 2, 'max_depth': 5, 'n_batches': 1, 'device': 'cpu'} 0.1 <function prm_double_tournament.<locals>.double_tournament at 0x0000028015D2FF60> 0.15 <function prm_hoist_mtn.<locals>.hoist_mtn at 0x0000028015CD9940> 0.7 <function swap_xo at 0x00000280152AEC00> True True logs/lactose/53_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 53
# cv_score: 0.72869986
# <function full at 0x00000280152AE520> 50 10 {'n_dims': 12, 'function_set': [sub, div, add, mul], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x00000280152B3350>, 'p_constants': 0.05, 'max_init_depth': 2, 'max_depth': 7, 'n_batches': 1, 'device': 'cpu'} 0.2 <function prm_rank_selection.<locals>.rank_selection at 0x0000028015D08540> 0.5 <function prm_subtree_mtn.<locals>.subtree_mtn at 0x0000028015BB56C0> 0.9 <function swap_xo at 0x00000280152AEC00> True False logs/lactose/54_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 54
# cv_score: 0.7124172
# <function grow at 0x00000280152AE340> 50 10 {'n_dims': 12, 'function_set': [mul, add, sub, div], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x00000280152B3350>, 'p_constants': 0.1, 'max_init_depth': 2, 'max_depth': 5, 'n_batches': 1, 'device': 'cpu'} 0.4 <function prm_rank_selection.<locals>.rank_selection at 0x0000028015D44040> 0.2 <function prm_subtree_mtn.<locals>.subtree_mtn at 0x0000028015D08540> 0.2 <function swap_xo at 0x00000280152AEC00> True False logs/lactose/55_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 55
# cv_score: 0.6209965
# <function grow at 0x00000280152AE340> 50 10 {'n_dims': 12, 'function_set': [mul, sub, add, div], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x00000280152B32D0>, 'p_constants': 0.1, 'max_init_depth': 2, 'max_depth': 8, 'n_batches': 1, 'device': 'cpu'} 0.1 <function prm_tournament.<locals>.tournament at 0x0000028015DA4EA0> 0.1 <function prm_hoist_mtn.<locals>.hoist_mtn at 0x0000028015D80220> 0.05 <function swap_xo at 0x00000280152AEC00> True True logs/lactose/56_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 56
# cv_score: 0.72869986
# <function grow at 0x00000280152AE340> 50 10 {'n_dims': 12, 'function_set': [sub, add, div], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x0000028014CC1850>, 'p_constants': 0.3, 'max_init_depth': 4, 'max_depth': 7, 'n_batches': 1, 'device': 'cpu'} 0.1 <function prm_double_tournament.<locals>.double_tournament at 0x0000028015E47D80> 0.05 <function prm_subtree_mtn.<locals>.subtree_mtn at 0x0000028015DA4360> 0.7 <function swap_xo at 0x00000280152AEC00> True False logs/lactose/57_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 57
# cv_score: 0.45564127
# <function full at 0x00000280152AE520> 50 10 {'n_dims': 12, 'function_set': [div, add], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x00000280152B3350>, 'p_constants': 0.3, 'max_init_depth': 3, 'max_depth': 7, 'n_batches': 1, 'device': 'cpu'} 0.2 <function prm_tournament.<locals>.tournament at 0x0000028015DA7A60> 0.1 <function prm_point_mtn.<locals>.point_mtn at 0x0000028015E17240> 0.05 <function swap_xo at 0x00000280152AEC00> False False logs/lactose/58_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 58
# cv_score: 0.73545474
# <function full at 0x00000280152AE520> 50 10 {'n_dims': 12, 'function_set': [mul, div, sub], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x00000280152B32D0>, 'p_constants': 0.3, 'max_init_depth': 5, 'max_depth': 5, 'n_batches': 1, 'device': 'cpu'} 0.2 <function prm_rank_selection.<locals>.rank_selection at 0x0000028015DF8B80> 0.1 <function prm_subtree_mtn.<locals>.subtree_mtn at 0x0000028015DA51C0> 0.5 <function swap_xo at 0x00000280152AEC00> False False logs/lactose/59_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 59
# cv_score: 39.30256
# <function full at 0x00000280152AE520> 50 10 {'n_dims': 12, 'function_set': [sub], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x00000280152B32D0>, 'p_constants': 0.05, 'max_init_depth': 5, 'max_depth': 8, 'n_batches': 1, 'device': 'cpu'} 0.3 <function prm_tournament.<locals>.tournament at 0x0000028015D823E0> 0.05 <function prm_subtree_mtn.<locals>.subtree_mtn at 0x0000028015DA4EA0> 0.9 <function swap_xo at 0x00000280152AEC00> True False logs/lactose/60_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 60
# cv_score: 0.8739379
# <function grow at 0x00000280152AE340> 50 10 {'n_dims': 12, 'function_set': [sub, mul, div, add], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x00000280152B3350>, 'p_constants': 0.05, 'max_init_depth': 2, 'max_depth': 5, 'n_batches': 1, 'device': 'cpu'} 0.1 <function prm_double_tournament.<locals>.double_tournament at 0x0000028015EA32E0> 0.1 <function prm_point_mtn.<locals>.point_mtn at 0x0000028015EFD080> 0.7 <function swap_xo at 0x00000280152AEC00> True True logs/lactose/61_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 61
# cv_score: 0.7115137
# <function grow at 0x00000280152AE340> 50 10 {'n_dims': 12, 'function_set': [mul, sub, add], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x00000280152B32D0>, 'p_constants': 0.1, 'max_init_depth': 3, 'max_depth': 8, 'n_batches': 1, 'device': 'cpu'} 0.1 <function prm_tournament.<locals>.tournament at 0x0000028015EFFBA0> 0.1 <function prm_subtree_mtn.<locals>.subtree_mtn at 0x0000028015EA0360> 0.8 <function swap_xo at 0x00000280152AEC00> True False logs/lactose/62_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 62
# cv_score: 0.24811251
# <function grow at 0x00000280152AE340> 50 10 {'n_dims': 12, 'function_set': [div], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x00000280152B3350>, 'p_constants': 0.3, 'max_init_depth': 2, 'max_depth': 5, 'n_batches': 1, 'device': 'cpu'} 0.05 <function prm_double_tournament.<locals>.double_tournament at 0x0000028015E97600> 0.15 <function prm_point_mtn.<locals>.point_mtn at 0x0000028015E97CE0> 0.5 <function swap_xo at 0x00000280152AEC00> False False logs/lactose/63_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 63
# cv_score: 0.90955096
# <function full at 0x00000280152AE520> 50 10 {'n_dims': 12, 'function_set': [add], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x0000028014CC1850>, 'p_constants': 0.05, 'max_init_depth': 5, 'max_depth': 6, 'n_batches': 1, 'device': 'cpu'} 0.2 <function prm_double_tournament.<locals>.double_tournament at 0x0000028015F4D940> 0.2 <function prm_subtree_mtn.<locals>.subtree_mtn at 0x0000028015E807C0> 0.5 <function swap_xo at 0x00000280152AEC00> False False logs/lactose/64_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 64
# cv_score: 0.64253163
# <function grow at 0x00000280152AE340> 50 10 {'n_dims': 12, 'function_set': [add, mul, div, sub], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x0000028014CC1850>, 'p_constants': 0.05, 'max_init_depth': 2, 'max_depth': 6, 'n_batches': 1, 'device': 'cpu'} 0.1 <function prm_double_tournament.<locals>.double_tournament at 0x0000028015F56520> 0.05 <function prm_subtree_mtn.<locals>.subtree_mtn at 0x0000028015F577E0> 0.9 <function swap_xo at 0x00000280152AEC00> True False logs/lactose/65_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 65
# cv_score: 0.61660874
# <function full at 0x00000280152AE520> 50 10 {'n_dims': 12, 'function_set': [sub, add, div], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x00000280152B32D0>, 'p_constants': 0.1, 'max_init_depth': 2, 'max_depth': 6, 'n_batches': 1, 'device': 'cpu'} 0.1 <function prm_tournament.<locals>.tournament at 0x0000028015ECCB80> 0.1 <function prm_hoist_mtn.<locals>.hoist_mtn at 0x0000028015F4D940> 0.05 <function swap_xo at 0x00000280152AEC00> False True logs/lactose/66_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 66
# cv_score: 1.4851335
# <function full at 0x00000280152AE520> 50 10 {'n_dims': 12, 'function_set': [add], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x00000280152B32D0>, 'p_constants': 0.1, 'max_init_depth': 4, 'max_depth': 8, 'n_batches': 1, 'device': 'cpu'} 0.05 <function prm_tournament.<locals>.tournament at 0x0000028015F6E520> 0.15 <function prm_point_mtn.<locals>.point_mtn at 0x0000028015F4EE80> 0.9 <function swap_xo at 0x00000280152AEC00> True True logs/lactose/67_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 67
# cv_score: 1.0110295
# <function full at 0x00000280152AE520> 50 10 {'n_dims': 12, 'function_set': [div, add, mul], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x0000028014CC1850>, 'p_constants': 0.05, 'max_init_depth': 2, 'max_depth': 7, 'n_batches': 1, 'device': 'cpu'} 0.2 <function prm_rank_selection.<locals>.rank_selection at 0x0000028015F2E980> 0.1 <function prm_hoist_mtn.<locals>.hoist_mtn at 0x0000028015F56520> 0.7 <function swap_xo at 0x00000280152AEC00> True True logs/lactose/68_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 68
# cv_score: 1.1462739
# <function full at 0x00000280152AE520> 50 10 {'n_dims': 12, 'function_set': [mul, div], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x00000280152B3350>, 'p_constants': 0.1, 'max_init_depth': 2, 'max_depth': 8, 'n_batches': 1, 'device': 'cpu'} 0.4 <function prm_double_tournament.<locals>.double_tournament at 0x0000028015F4E160> 0.1 <function prm_hoist_mtn.<locals>.hoist_mtn at 0x0000028015F2C7C0> 0.2 <function swap_xo at 0x00000280152AEC00> False True logs/lactose/69_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 69
# cv_score: 2.238359
# <function grow at 0x00000280152AE340> 50 10 {'n_dims': 12, 'function_set': [add, div, mul], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x0000028014CC1850>, 'p_constants': 0.3, 'max_init_depth': 3, 'max_depth': 6, 'n_batches': 1, 'device': 'cpu'} 0.05 <function prm_rank_selection.<locals>.rank_selection at 0x0000028015F6E520> 0.2 <function prm_point_mtn.<locals>.point_mtn at 0x0000028015D823E0> 0.5 <function swap_xo at 0x00000280152AEC00> False True logs/lactose/70_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 70
# cv_score: 1.4257728
# <function grow at 0x00000280152AE340> 50 10 {'n_dims': 12, 'function_set': [div, sub], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x0000028014CC1850>, 'p_constants': 0.1, 'max_init_depth': 4, 'max_depth': 5, 'n_batches': 1, 'device': 'cpu'} 0.05 <function prm_tournament.<locals>.tournament at 0x0000028015F2C7C0> 0.5 <function prm_hoist_mtn.<locals>.hoist_mtn at 0x0000028015F577E0> 0.05 <function swap_xo at 0x00000280152AEC00> True True logs/lactose/71_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 71
# cv_score: 2.1037965
# <function full at 0x00000280152AE520> 50 10 {'n_dims': 12, 'function_set': [mul, div, add], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x0000028014CC1850>, 'p_constants': 0.05, 'max_init_depth': 5, 'max_depth': 8, 'n_batches': 1, 'device': 'cpu'} 0.4 <function prm_double_tournament.<locals>.double_tournament at 0x000002801603EE80> 0.1 <function prm_point_mtn.<locals>.point_mtn at 0x0000028016035620> 0.7 <function swap_xo at 0x00000280152AEC00> False False logs/lactose/72_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 72
# cv_score: 3.6029553
# <function full at 0x00000280152AE520> 50 10 {'n_dims': 12, 'function_set': [add, div, mul], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x00000280152B3350>, 'p_constants': 0.05, 'max_init_depth': 3, 'max_depth': 6, 'n_batches': 1, 'device': 'cpu'} 0.3 <function prm_tournament.<locals>.tournament at 0x000002801603C360> 0.5 <function prm_subtree_mtn.<locals>.subtree_mtn at 0x0000028016007B00> 0.8 <function swap_xo at 0x00000280152AEC00> False False logs/lactose/73_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 73
# cv_score: 1.0059283
# <function grow at 0x00000280152AE340> 50 10 {'n_dims': 12, 'function_set': [div, mul, sub, add], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x0000028014CC1850>, 'p_constants': 0.05, 'max_init_depth': 4, 'max_depth': 5, 'n_batches': 1, 'device': 'cpu'} 0.4 <function prm_double_tournament.<locals>.double_tournament at 0x00000280160B3A60> 0.5 <function prm_point_mtn.<locals>.point_mtn at 0x0000028016065760> 0.05 <function swap_xo at 0x00000280152AEC00> False True logs/lactose/74_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 74
# cv_score: 0.37785527
# <function grow at 0x00000280152AE340> 50 10 {'n_dims': 12, 'function_set': [add, sub, mul, div], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x00000280152B32D0>, 'p_constants': 0.3, 'max_init_depth': 3, 'max_depth': 5, 'n_batches': 1, 'device': 'cpu'} 0.2 <function prm_double_tournament.<locals>.double_tournament at 0x000002801613E160> 0.2 <function prm_point_mtn.<locals>.point_mtn at 0x0000028015F6E520> 0.2 <function swap_xo at 0x00000280152AEC00> False True logs/lactose/75_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 75
# cv_score: 0.4606995
# <function full at 0x00000280152AE520> 50 10 {'n_dims': 12, 'function_set': [sub, mul], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x00000280152B32D0>, 'p_constants': 0.2, 'max_init_depth': 5, 'max_depth': 8, 'n_batches': 1, 'device': 'cpu'} 0.3 <function prm_rank_selection.<locals>.rank_selection at 0x00000280161220C0> 0.5 <function prm_subtree_mtn.<locals>.subtree_mtn at 0x0000028016035620> 0.2 <function swap_xo at 0x00000280152AEC00> True True logs/lactose/76_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 76
# cv_score: 2.7006218
# ...
# cv_score: 1.247814
# <function grow at 0x00000280152AE340> 50 10 {'n_dims': 12, 'function_set': [mul, sub, div, add], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x00000280152B3350>, 'p_constants': 0.3, 'max_init_depth': 5, 'max_depth': 8, 'n_batches': 1, 'device': 'cpu'} 0.3 <function prm_double_tournament.<locals>.double_tournament at 0x0000028017133740> 0.15 <function prm_point_mtn.<locals>.point_mtn at 0x00000280171A6340> 0.2 <function swap_xo at 0x00000280152AEC00> False True logs/lactose/175_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 175
# cv_score: 0.6354078
# <function grow at 0x00000280152AE340> 50 10 {'n_dims': 12, 'function_set': [div], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x0000028014CC1850>, 'p_constants': 0.3, 'max_init_depth': 2, 'max_depth': 6, 'n_batches': 1, 'device': 'cpu'} 0.4 <function prm_rank_selection.<locals>.rank_selection at 0x000002801716E520> 0.2 <function prm_point_mtn.<locals>.point_mtn at 0x0000028017236CA0> 0.7 <function swap_xo at 0x00000280152AEC00> True False logs/lactose/176_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 176
# cv_score: 1.6131489
# <function full at 0x00000280152AE520> 50 10 {'n_dims': 12, 'function_set': [add, mul, div], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x00000280152B3350>, 'p_constants': 0.1, 'max_init_depth': 5, 'max_depth': 7, 'n_batches': 1, 'device': 'cpu'} 0.3 <function prm_double_tournament.<locals>.double_tournament at 0x00000280171FBF60> 0.1 <function prm_hoist_mtn.<locals>.hoist_mtn at 0x0000028017234EA0> 0.9 <function swap_xo at 0x00000280152AEC00> True False logs/lactose/177_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 177
# cv_score: 1.3211204
# <function grow at 0x00000280152AE340> 50 10 {'n_dims': 12, 'function_set': [sub, div, mul, add], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x00000280152B3350>, 'p_constants': 0.1, 'max_init_depth': 3, 'max_depth': 6, 'n_batches': 1, 'device': 'cpu'} 0.2 <function prm_rank_selection.<locals>.rank_selection at 0x00000280172393A0> 0.5 <function prm_point_mtn.<locals>.point_mtn at 0x00000280171E4400> 0.8 <function swap_xo at 0x00000280152AEC00> True True logs/lactose/178_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 178
# cv_score: 0.6568335
# <function full at 0x00000280152AE520> 50 10 {'n_dims': 12, 'function_set': [sub], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x00000280152B3350>, 'p_constants': 0.1, 'max_init_depth': 5, 'max_depth': 5, 'n_batches': 1, 'device': 'cpu'} 0.4 <function prm_rank_selection.<locals>.rank_selection at 0x0000028017232DE0> 0.5 <function prm_point_mtn.<locals>.point_mtn at 0x0000028017299BC0> 0.05 <function swap_xo at 0x00000280152AEC00> True False logs/lactose/179_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 179
# cv_score: 2.8789136
# <function grow at 0x00000280152AE340> 50 10 {'n_dims': 12, 'function_set': [add, div, mul], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x00000280152B3350>, 'p_constants': 0.2, 'max_init_depth': 3, 'max_depth': 6, 'n_batches': 1, 'device': 'cpu'} 0.3 <function prm_double_tournament.<locals>.double_tournament at 0x00000280171E4400> 0.1 <function prm_point_mtn.<locals>.point_mtn at 0x0000028017299760> 0.9 <function swap_xo at 0x00000280152AEC00> False True logs/lactose/180_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 180
# cv_score: 1.2597307
# <function full at 0x00000280152AE520> 50 10 {'n_dims': 12, 'function_set': [mul, sub, add], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x0000028014CC1850>, 'p_constants': 0.05, 'max_init_depth': 5, 'max_depth': 7, 'n_batches': 1, 'device': 'cpu'} 0.4 <function prm_double_tournament.<locals>.double_tournament at 0x0000028017318FE0> 0.5 <function prm_point_mtn.<locals>.point_mtn at 0x0000028017266340> 0.2 <function swap_xo at 0x00000280152AEC00> False True logs/lactose/181_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 181
# cv_score: 4.8932853
# <function full at 0x00000280152AE520> 50 10 {'n_dims': 12, 'function_set': [mul, sub], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x0000028014CC1850>, 'p_constants': 0.3, 'max_init_depth': 3, 'max_depth': 7, 'n_batches': 1, 'device': 'cpu'} 0.4 <function prm_double_tournament.<locals>.double_tournament at 0x00000280173627A0> 0.5 <function prm_subtree_mtn.<locals>.subtree_mtn at 0x0000028017319580> 0.9 <function swap_xo at 0x00000280152AEC00> False False logs/lactose/182_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 182
# cv_score: 0.37324673
# <function grow at 0x00000280152AE340> 50 10 {'n_dims': 12, 'function_set': [div, sub, add], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x00000280152B3350>, 'p_constants': 0.05, 'max_init_depth': 2, 'max_depth': 6, 'n_batches': 1, 'device': 'cpu'} 0.2 <function prm_tournament.<locals>.tournament at 0x00000280172A9F80> 0.15 <function prm_subtree_mtn.<locals>.subtree_mtn at 0x000002801731B240> 0.2 <function swap_xo at 0x00000280152AEC00> True False logs/lactose/183_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 183
# cv_score: 0.5965242
# <function full at 0x00000280152AE520> 50 10 {'n_dims': 12, 'function_set': [mul, add, sub], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x0000028014CC1850>, 'p_constants': 0.2, 'max_init_depth': 4, 'max_depth': 7, 'n_batches': 1, 'device': 'cpu'} 0.4 <function prm_double_tournament.<locals>.double_tournament at 0x000002801733E980> 0.5 <function prm_subtree_mtn.<locals>.subtree_mtn at 0x00000280171E4400> 0.8 <function swap_xo at 0x00000280152AEC00> True False logs/lactose/184_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 184
# cv_score: 0.579151
# <function grow at 0x00000280152AE340> 50 10 {'n_dims': 12, 'function_set': [div, mul, sub, add], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x00000280152B32D0>, 'p_constants': 0.3, 'max_init_depth': 2, 'max_depth': 8, 'n_batches': 1, 'device': 'cpu'} 0.1 <function prm_rank_selection.<locals>.rank_selection at 0x00000280173BD9E0> 0.5 <function prm_point_mtn.<locals>.point_mtn at 0x000002801733C540> 0.9 <function swap_xo at 0x00000280152AEC00> True True logs/lactose/185_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 185
# cv_score: 0.5948993
# <function grow at 0x00000280152AE340> 50 10 {'n_dims': 12, 'function_set': [sub, mul], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x00000280152B32D0>, 'p_constants': 0.05, 'max_init_depth': 4, 'max_depth': 6, 'n_batches': 1, 'device': 'cpu'} 0.1 <function prm_rank_selection.<locals>.rank_selection at 0x00000280172F07C0> 0.5 <function prm_point_mtn.<locals>.point_mtn at 0x00000280173BC0E0> 0.8 <function swap_xo at 0x00000280152AEC00> False True logs/lactose/186_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 186
# cv_score: 2.1487486
# <function grow at 0x00000280152AE340> 50 10 {'n_dims': 12, 'function_set': [div, sub], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x0000028014CC1850>, 'p_constants': 0.2, 'max_init_depth': 2, 'max_depth': 5, 'n_batches': 1, 'device': 'cpu'} 0.05 <function prm_rank_selection.<locals>.rank_selection at 0x00000280173AA340> 0.5 <function prm_subtree_mtn.<locals>.subtree_mtn at 0x00000280172156C0> 0.05 <function swap_xo at 0x00000280152AEC00> True True logs/lactose/187_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 187
# cv_score: 0.47906184
# <function grow at 0x00000280152AE340> 50 10 {'n_dims': 12, 'function_set': [add, div, sub, mul], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x0000028014CC1850>, 'p_constants': 0.3, 'max_init_depth': 5, 'max_depth': 5, 'n_batches': 1, 'device': 'cpu'} 0.1 <function prm_tournament.<locals>.tournament at 0x000002801733D8A0> 0.2 <function prm_subtree_mtn.<locals>.subtree_mtn at 0x00000280173AA340> 0.8 <function swap_xo at 0x00000280152AEC00> False False logs/lactose/188_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 188
# cv_score: 0.46007842
# <function grow at 0x00000280152AE340> 50 10 {'n_dims': 12, 'function_set': [div], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x00000280152B32D0>, 'p_constants': 0.1, 'max_init_depth': 2, 'max_depth': 6, 'n_batches': 1, 'device': 'cpu'} 0.1 <function prm_tournament.<locals>.tournament at 0x00000280172156C0> 0.15 <function prm_subtree_mtn.<locals>.subtree_mtn at 0x00000280173691C0> 0.2 <function swap_xo at 0x00000280152AEC00> False True logs/lactose/189_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 189
# cv_score: 1.072067
# <function grow at 0x00000280152AE340> 50 10 {'n_dims': 12, 'function_set': [add, mul, div, sub], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x00000280152B32D0>, 'p_constants': 0.2, 'max_init_depth': 3, 'max_depth': 5, 'n_batches': 1, 'device': 'cpu'} 0.4 <function prm_tournament.<locals>.tournament at 0x00000280173BE700> 0.15 <function prm_point_mtn.<locals>.point_mtn at 0x000002801745A5C0> 0.05 <function swap_xo at 0x00000280152AEC00> False True logs/lactose/190_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 190
# cv_score: 0.69786227
# <function full at 0x00000280152AE520> 50 10 {'n_dims': 12, 'function_set': [mul, sub, add], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x00000280152B32D0>, 'p_constants': 0.1, 'max_init_depth': 3, 'max_depth': 6, 'n_batches': 1, 'device': 'cpu'} 0.3 <function prm_double_tournament.<locals>.double_tournament at 0x00000280174DA840> 0.1 <function prm_subtree_mtn.<locals>.subtree_mtn at 0x00000280174DB1A0> 0.9 <function swap_xo at 0x00000280152AEC00> False True logs/lactose/191_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 191
# cv_score: 0.64253163
# <function full at 0x00000280152AE520> 50 10 {'n_dims': 12, 'function_set': [sub, mul, div, add], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x00000280152B32D0>, 'p_constants': 0.3, 'max_init_depth': 3, 'max_depth': 8, 'n_batches': 1, 'device': 'cpu'} 0.3 <function prm_rank_selection.<locals>.rank_selection at 0x000002801744B9C0> 0.05 <function prm_subtree_mtn.<locals>.subtree_mtn at 0x0000028017401E40> 0.9 <function swap_xo at 0x00000280152AEC00> False False logs/lactose/192_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 192
# cv_score: 1.5152773
# <function full at 0x00000280152AE520> 50 10 {'n_dims': 12, 'function_set': [mul, div], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x00000280152B3350>, 'p_constants': 0.3, 'max_init_depth': 4, 'max_depth': 6, 'n_batches': 1, 'device': 'cpu'} 0.2 <function prm_tournament.<locals>.tournament at 0x000002801741AE80> 0.05 <function prm_point_mtn.<locals>.point_mtn at 0x000002801744A660> 0.2 <function swap_xo at 0x00000280152AEC00> False False logs/lactose/193_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 193
# cv_score: 3.8128319
# <function grow at 0x00000280152AE340> 50 10 {'n_dims': 12, 'function_set': [mul, div, add], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x0000028014CC1850>, 'p_constants': 0.05, 'max_init_depth': 2, 'max_depth': 5, 'n_batches': 1, 'device': 'cpu'} 0.1 <function prm_double_tournament.<locals>.double_tournament at 0x00000280174CFF60> 0.15 <function prm_hoist_mtn.<locals>.hoist_mtn at 0x00000280174CC7C0> 0.7 <function swap_xo at 0x00000280152AEC00> True True logs/lactose/194_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 194
# cv_score: 0.72869986
# <function full at 0x00000280152AE520> 50 10 {'n_dims': 12, 'function_set': [sub, div, add, mul], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x00000280152B3350>, 'p_constants': 0.05, 'max_init_depth': 2, 'max_depth': 7, 'n_batches': 1, 'device': 'cpu'} 0.2 <function prm_rank_selection.<locals>.rank_selection at 0x0000028017504680> 0.5 <function prm_subtree_mtn.<locals>.subtree_mtn at 0x00000280174CD080> 0.9 <function swap_xo at 0x00000280152AEC00> True False logs/lactose/195_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 195
# cv_score: 0.7124172
# <function grow at 0x00000280152AE340> 50 10 {'n_dims': 12, 'function_set': [mul, add, sub, div], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x00000280152B3350>, 'p_constants': 0.1, 'max_init_depth': 2, 'max_depth': 5, 'n_batches': 1, 'device': 'cpu'} 0.4 <function prm_rank_selection.<locals>.rank_selection at 0x00000280175CB920> 0.2 <function prm_subtree_mtn.<locals>.subtree_mtn at 0x00000280174B0E00> 0.2 <function swap_xo at 0x00000280152AEC00> True False logs/lactose/196_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 196
# cv_score: 0.6209965
# <function grow at 0x00000280152AE340> 50 10 {'n_dims': 12, 'function_set': [mul, sub, add, div], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x00000280152B32D0>, 'p_constants': 0.1, 'max_init_depth': 2, 'max_depth': 8, 'n_batches': 1, 'device': 'cpu'} 0.1 <function prm_tournament.<locals>.tournament at 0x00000280175EAC00> 0.1 <function prm_hoist_mtn.<locals>.hoist_mtn at 0x0000028017497920> 0.05 <function swap_xo at 0x00000280152AEC00> True True logs/lactose/197_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 197
# cv_score: 0.72869986
# <function grow at 0x00000280152AE340> 50 10 {'n_dims': 12, 'function_set': [sub, add, div], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x0000028014CC1850>, 'p_constants': 0.3, 'max_init_depth': 4, 'max_depth': 7, 'n_batches': 1, 'device': 'cpu'} 0.1 <function prm_double_tournament.<locals>.double_tournament at 0x000002801761A340> 0.05 <function prm_subtree_mtn.<locals>.subtree_mtn at 0x00000280174CFF60> 0.7 <function swap_xo at 0x00000280152AEC00> True False logs/lactose/198_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 198
# cv_score: 0.45564127
# <function full at 0x00000280152AE520> 50 10 {'n_dims': 12, 'function_set': [div, add], 'constant_set': <gpolnel.operators.initializers.ERC object at 0x00000280152B3350>, 'p_constants': 0.3, 'max_init_depth': 3, 'max_depth': 7, 'n_batches': 1, 'device': 'cpu'} 0.2 <function prm_tournament.<locals>.tournament at 0x00000280174B0E00> 0.1 <function prm_point_mtn.<locals>.point_mtn at 0x0000028017497920> 0.05 <function swap_xo at 0x00000280152AEC00> False False logs/lactose/199_cv_results.csv logs/lactose/train_logs.csv <gpolnel.utils.ffunctions.Ffunctions object at 0x000002803E47CAD0> 1 cpu 199
# cv_score: 0.73545474

# %%
# best_params = load_best_params(f'{target}' + '-best_params-' + '3' +'.pkl')

# if 'rank' in best_params['selection_method']:
#     best_params['selection_method'] = prm_rank_selection()
# elif 'roulette' in best_params['selection_method']:
#     best_params['selection_method'] = prm_roulette_wheel()
# elif 'tournament' in best_params['selection_method']:
#     best_params['selection_method'] = prm_tournament(best_params['selection_pressure'])

# if 'subtree' in best_params['mutation_method']:
#     best_params['mutation_method'] = prm_subtree_mtn(initializer=prm_grow(sspace=best_params['sspace']))
# elif 'hoist' in best_params['mutation_method']:
#     best_params['mutation_method'] = prm_hoist_mtn()
# elif 'point' in best_params['mutation_method']:
#     best_params['mutation_method'] = prm_point_mtn(sspace=best_params['sspace'], prob=best_params['mutation_prob'])

# if 'swap' in best_params['xo_method']:
#     best_params['xo_method'] = swap_xo

# %%
# score = gp_cross_validation(best_params['X'], best_params['y'], best_params['batch_size'], best_params['shuffle'], best_params['kfold'], 
#                                 initializer=best_params['initializer'], ps=best_params['ps'], n_iter=best_params['n_iter'], 
#                                 sspace=best_params['sspace'],  
#                                 selection_method=best_params['selection_method'],
#                                 mutation_prob=best_params['mutation_prob'],
#                                 mutation_method= best_params['mutation_method'],
#                                 xo_prob=best_params['xo_prob'], xo_method= best_params['xo_method'],
#                                 has_elitism=best_params['has_elitism'],
#                                 allow_reproduction=best_params['allow_reproduction'],
#                                 log_path_cv='logs/lactose/best_cv.csv', log_path_train='logs/lactose/best_train.csv',
#                                 ffunction=best_params['ffunction'], seed=best_params['seed'], device=best_params['device'], id=0)
